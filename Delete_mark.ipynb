# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline 
import pandas as pd 
import seaborn as sns 
import sklearn

# %%
url = "https://raw.githubusercontent.com/samarkinav/ML/main/students.csv"
data_raw = pd.read_csv(url)

# %%
data_raw.shape
# Out:
# (1045, 33)

# %%
data_raw.drop([395], inplace = True)

# %%
data_raw.shape
# Out:
# (1044, 33)

# %%
data_raw['G3'] = data_raw['G3'].astype(str).astype(int)

# %%
def func(G3):
    if G3 < 10:
        return 'fail'
    else:
        return 'passed'
    
data_raw['Mark'] = data_raw.apply(lambda x: func(x.G3), axis = 1)

# %%
data_raw.head()
# Out:
#   school sex age address famsize Pstatus Medu Fedu     Mjob      Fjob  ...  \
# 0     GP   F  18       U     GT3       A    4    4  at_home   teacher  ...
# 1     GP   F  17       U     GT3       T    1    1  at_home     other  ...
# 2     GP   F  15       U     LE3       T    1    1  at_home     other  ...
# 3     GP   F  15       U     GT3       T    4    2   health  services  ...
# 4     GP   F  16       U     GT3       T    3    3    other     other  ...
#
#   freetime goout Dalc Walc health absences  G1  G2  G3    Mark
# 0        3     4    1    1      3        6   5   6   6    fail
# 1        3     3    1    1      3        4   5   5   6    fail
# 2        3     2    2    3      3       10   7   8  10  passed
# 3        2     2    1    1      5        2  15  14  15  passed
# 4        3     2    1    2      5        4   6  10  10  passed
#
# [5 rows x 34 columns]

# %%
data_raw.drop('G1', axis = 1, inplace = True)

# %%
data_raw.drop('G2', axis = 1, inplace = True)

# %%
data_raw.drop('G3', axis = 1, inplace = True)

# %%
data_raw.head()
# Out:
#   school sex age address famsize Pstatus Medu Fedu     Mjob      Fjob  ...  \
# 0     GP   F  18       U     GT3       A    4    4  at_home   teacher  ...
# 1     GP   F  17       U     GT3       T    1    1  at_home     other  ...
# 2     GP   F  15       U     LE3       T    1    1  at_home     other  ...
# 3     GP   F  15       U     GT3       T    4    2   health  services  ...
# 4     GP   F  16       U     GT3       T    3    3    other     other  ...
#
#   internet romantic famrel freetime goout Dalc Walc health absences    Mark
# 0       no       no      4        3     4    1    1      3        6    fail
# 1      yes       no      5        3     3    1    1      3        4    fail
# 2      yes       no      4        3     2    2    3      3       10  passed
# 3      yes      yes      3        2     2    1    1      5        2  passed
# 4       no       no      4        3     2    1    2      5        4  passed
#
# [5 rows x 31 columns]

# %%
data_raw
# Out:
#      school sex age address famsize Pstatus Medu Fedu      Mjob      Fjob  \
# 0        GP   F  18       U     GT3       A    4    4   at_home   teacher
# 1        GP   F  17       U     GT3       T    1    1   at_home     other
# 2        GP   F  15       U     LE3       T    1    1   at_home     other
# 3        GP   F  15       U     GT3       T    4    2    health  services
# 4        GP   F  16       U     GT3       T    3    3     other     other
# ...     ...  ..  ..     ...     ...     ...  ...  ...       ...       ...
# 1040     MS   F  19       R     GT3       T    2    3  services     other
# 1041     MS   F  18       U     LE3       T    3    1   teacher  services
# 1042     MS   F  18       U     GT3       T    1    1     other     other
# 1043     MS   M  17       U     LE3       T    3    1  services  services
# 1044     MS   M  18       R     LE3       T    3    2  services     other
#
#       ... internet romantic famrel freetime goout Dalc Walc health absences  \
# ...

# %%
data_raw.to_csv('students_2.csv', index = False)
